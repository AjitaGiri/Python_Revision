# %% [markdown]
# # oop in python

# %% [markdown]
# ## 1. Basic class and object
# Create a Car class with attributes like brand and model. Then create an instance of this class.

# %%
class Car:
 def __init__(self,brand,model):
    self.brand=brand
    self.model=model

c1=Car('Mercedes','BMW')
print(c1.brand, c1.model)
# Out:
# Mercedes BMW

# %% [markdown]
# ## 2. Class method and self
# Add a method to the Car class that displays the full name of the car(brand and model)

# %%
class Car:
 def __init__(self,brand,model):
    self.brand=brand
    self.model=model

 def display(self):
    #print('The brand and model of car is',self.brand, self.model)
    print(f'The brand and model of car is {self.brand} {self.model}')


c1=Car('Mercedes','BMW')
c1.display()
# Out:
# The brand and model of car is Mercedes BMW

# %% [markdown]
# ## 3. Inheritance
# Create an ElectricCar class that inherits from the Car class and has an additional attribute

# %%
class Car:
 def __init__(self,brand,model):
    self.brand=brand
    self.model=model

 def display(self):
    #print('The brand and model of car is',self.brand, self.model)
    print(f'The brand and model of car is {self.brand} {self.model}')

class ElectricCar(Car):
    def __init__(self,battery_size,brand,model):
        super().__init__(brand,model)
        self.battery_size=battery_size

e1=ElectricCar('85kwh','Tesla','Model S')
e1.display()
# Out:
# The brand and model of car is Tesla Model S

# %% [markdown]
# ## 4. Encapsulation
# Modify the Car class to encapsulate the brand attribute, making it private, and provide a getter method for it.

# %%
class Car:
    def __init__(self,brand,model):
        self.__brand=brand
        self.__model=model

    def get_brand(self):
        return f'{self.__brand}'

    def display(self):
        return f'{self.__brand} {self.__model}'

c1=Car('Tesla','Model s')
print(c1.display())
# Out:
# Tesla Model s

# %% [markdown]
# ## 5. Polymorphism
# Demonstrate polymorphism

# %%
class Complex:
    def __init__(self,real,img):
        self.real=real
        self.img=img

    def __add__(self,num2):
        newReal=self.real+num2.real
        newImg=self.img+num2.img
        return Complex(newReal,newImg)
        
    def display(self):
        return f'{self.real}i+{self.img}j'

num1=Complex(2,3)
num2=Complex(1,4)
print(num1.display())
print(num2.display())
num3=num1+num2
print(num3.display())
# Out:
# 2i+3j
# 1i+4j
# 3i+7j
